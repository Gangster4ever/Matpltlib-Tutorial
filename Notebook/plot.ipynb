# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.linspace(1, 100, 20)
y= np.random.randint(1, 5, 20)
fig, ax = plt.subplots(dpi=120)
ax.plot(x, y, c='orange', ls='-.', marker='_')
